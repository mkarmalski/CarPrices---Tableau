# %% [markdown]
# ## Import Bibliotek

# %%
import pandas as pd
import numpy as np

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
import xgboost as xgb

import eli5

# %% [markdown]
# ## Upload danych

# %%
df = pd.read_csv('car_prices.csv')
df = df.fillna(-1)
df.head()
# Out:
#    year        make  model                    trim   body transmission  \
# 0  2015  volkswagen  Jetta  SE PZEV w/Connectivity  sedan    automatic
# 1  2015  volkswagen  Jetta  SE PZEV w/Connectivity  sedan    automatic
# 2  2015  volkswagen  Jetta  SE PZEV w/Connectivity  sedan    automatic
# 3  2015  volkswagen  Jetta  SE PZEV w/Connectivity  sedan    automatic
# 4  2015  volkswagen  Jetta  SE PZEV w/Connectivity  sedan    automatic
#
#                  vin state  condition  odometer   color interior  \
# 0  3vwd17aj0fm227318    fl        4.1   14872.0    gray    black
# 1  3vwd17aj5fm219943    fl        4.4   16633.0  silver    black
# 2  3vwd17aj5fm221322    fl        4.8   18384.0  silver    black
# 3  3vwd17aj5fm273601    fl        2.8     339.0   black    black
# 4  3vwd17aj6fm218641    fl        4.9   12655.0     red    black
#
#                            seller    mmr  sellingprice  \
# 0  enterprise veh exchange/rental  13700         14300
# 1             sixt rent a car llc  13600         13600
# 2             sixt rent a car llc  13550         13500
# 3    florida auto financial group  14300         12900
# 4  enterprise veh exchange/rental  13850         14500
#
#                                   saledate
# 0  Tue Jun 02 2015 02:15:00 GMT-0700 (PDT)
# 1  Tue Jun 02 2015 02:15:00 GMT-0700 (PDT)
# 2  Tue Jun 02 2015 02:15:00 GMT-0700 (PDT)
# 3  Tue Jun 02 2015 02:30:00 GMT-0700 (PDT)
# 4  Tue May 26 2015 02:15:00 GMT-0700 (PDT)

# %% [markdown]
# ## Cechy

# %%
num_feats = ['odometer','year','condition']
obj_feats = ['make','body','transmission','color','interior']

for feat in obj_feats:
    df["{}_cat".format(feat)] = df[feat].factorize()[0]
    
cat_feats = [x for x in df.columns if "_cat" in x]
feats = cat_feats + num_feats
df.head()
# Out:
#    year        make  model                    trim   body transmission  \
# 0  2015  volkswagen  Jetta  SE PZEV w/Connectivity  sedan    automatic
# 1  2015  volkswagen  Jetta  SE PZEV w/Connectivity  sedan    automatic
# 2  2015  volkswagen  Jetta  SE PZEV w/Connectivity  sedan    automatic
# 3  2015  volkswagen  Jetta  SE PZEV w/Connectivity  sedan    automatic
# 4  2015  volkswagen  Jetta  SE PZEV w/Connectivity  sedan    automatic
#
#                  vin state  condition  odometer  ... interior  \
# 0  3vwd17aj0fm227318    fl        4.1   14872.0  ...    black
# 1  3vwd17aj5fm219943    fl        4.4   16633.0  ...    black
# 2  3vwd17aj5fm221322    fl        4.8   18384.0  ...    black
# 3  3vwd17aj5fm273601    fl        2.8     339.0  ...    black
# 4  3vwd17aj6fm218641    fl        4.9   12655.0  ...    black
#
#                            seller    mmr  sellingprice  \
# 0  enterprise veh exchange/rental  13700         14300
# 1             sixt rent a car llc  13600         13600
# 2             sixt rent a car llc  13550         13500
# 3    florida auto financial group  14300         12900
# 4  enterprise veh exchange/rental  13850         14500
#
#                                   saledate make_cat  body_cat  \
# 0  Tue Jun 02 2015 02:15:00 GMT-0700 (PDT)        0         0
# 1  Tue Jun 02 2015 02:15:00 GMT-0700 (PDT)        0         0
# 2  Tue Jun 02 2015 02:15:00 GMT-0700 (PDT)        0         0
# 3  Tue Jun 02 2015 02:30:00 GMT-0700 (PDT)        0         0
# 4  Tue May 26 2015 02:15:00 GMT-0700 (PDT)        0         0
#
#    transmission_cat  color_cat  interior_cat
# 0                 0          0             0
# 1                 0          1             0
# 2                 0          1             0
# 3                 0          2             0
# 4                 0          3             0
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Pierwszy model - drzewo decyzyjne i las losowy

# %%
X = df[feats]
y = df["sellingprice"]

model = DecisionTreeRegressor(max_depth=5)
model.fit(X, y)
y_pred = model.predict(X)

mean_absolute_error(y, y_pred)
# Out:
# 4273.5898273119055

# %%
X = df[feats]
y = df["sellingprice"]

model = RandomForestRegressor(max_depth=5)
model.fit(X, y)
y_pred = model.predict(X)

mean_absolute_error(y, y_pred)
# Out:
# 4204.228560689692

# %% [markdown]
# ## Drugi model - xgboost

# %%
X = df[feats]
y = df["sellingprice"]

model = xgb.XGBRegressor(max_depth=5, n_estimators=50, learning_rate=0.3, random_state=0)
model.fit(X, y)
y_pred = model.predict(X)

mean_absolute_error(y, y_pred)
# Out:
# 2610.037748873653

# %% [markdown]
# ## Jak usprawnić model:
#
#
#  1 - feature engineering - tworzymy cechy z już istniejących (np. wersje wyposażenia)
#
#  2 - feature engineering - cechy numeryczne zagregowane po markach, latach
#
#  3 - dobór modelu i optymalizacja parametrów, walidacja krzyżowa
#
#  4 - prognoza na logarytmie (zmiana rozkładu)

# %% [markdown]
# ## Ważność cech

# %%
eli5.show_weights(model, feature_names=feats)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.3592
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 odometer
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.47%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2275
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 year
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.25%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1287
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 body_cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.61%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1219
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 make_cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.29%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0920
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 condition
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.98%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0499
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 interior_cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.21%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0114
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 color_cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.43%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0095
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 transmission_cat
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %% [markdown]
# # ---> idziemy do Tableau --->

# %% [markdown]
# # -------------------------------------------------------------

# %% [markdown]
# ## Uproszczony model do deployementu:

# %%
X = df[num_feats]
y = df["sellingprice"]

model = DecisionTreeRegressor(max_depth=5)
model.fit(X, y)
y_pred = model.predict(X)

mean_absolute_error(y, y_pred)
# Out:
# 4813.227554932031

# %% [markdown]
# ## Funkcja i deployement

# %%
def price_prediction(_arg1,_arg2,_arg3):    
    
    input_data = np.column_stack([_arg1,_arg2,_arg3])
    
    X = pd.DataFrame(input_data,columns=['odometer','year','condition'])
   
    X = X.fillna(-1).values
   
    result = model.predict(X)
    
    return result.tolist()

# %%
price_prediction(100000,2015,1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# [5808.224585436194]

# %%
from tabpy.tabpy_tools.client import Client

client = Client('http://localhost:9004/')
client.deploy('price_prediction',
price_prediction,
'price_prediction'
, override = True)

# %% [markdown]
# # ---> idziemy do Tableau --->

# %% [markdown]
# # -------------------------------------------------------------

# %% [markdown]
# ## Mapujemy rynek

# %%
#dołączamy dane do prognozy

df_test = pd.read_csv('full.csv')

df_train = pd.read_csv('car_prices.csv')
df_train = df_train.fillna(-1)

df = pd.concat([df_train,df_test])

df.head()
# Out:
#    year        make  model                    trim   body transmission  \
# 0  2015  volkswagen  Jetta  SE PZEV w/Connectivity  sedan    automatic
# 1  2015  volkswagen  Jetta  SE PZEV w/Connectivity  sedan    automatic
# 2  2015  volkswagen  Jetta  SE PZEV w/Connectivity  sedan    automatic
# 3  2015  volkswagen  Jetta  SE PZEV w/Connectivity  sedan    automatic
# 4  2015  volkswagen  Jetta  SE PZEV w/Connectivity  sedan    automatic
#
#                  vin state  condition  odometer   color interior  \
# 0  3vwd17aj0fm227318    fl        4.1   14872.0    gray    black
# 1  3vwd17aj5fm219943    fl        4.4   16633.0  silver    black
# 2  3vwd17aj5fm221322    fl        4.8   18384.0  silver    black
# 3  3vwd17aj5fm273601    fl        2.8     339.0   black    black
# 4  3vwd17aj6fm218641    fl        4.9   12655.0     red    black
#
#                            seller      mmr  sellingprice  \
# 0  enterprise veh exchange/rental  13700.0       14300.0
# 1             sixt rent a car llc  13600.0       13600.0
# 2             sixt rent a car llc  13550.0       13500.0
# 3    florida auto financial group  14300.0       12900.0
# 4  enterprise veh exchange/rental  13850.0       14500.0
#
#                                   saledate
# 0  Tue Jun 02 2015 02:15:00 GMT-0700 (PDT)
# 1  Tue Jun 02 2015 02:15:00 GMT-0700 (PDT)
# 2  Tue Jun 02 2015 02:15:00 GMT-0700 (PDT)
# 3  Tue Jun 02 2015 02:30:00 GMT-0700 (PDT)
# 4  Tue May 26 2015 02:15:00 GMT-0700 (PDT)

# %%
#tworzymy cechy

num_feats = ['odometer','year','condition']
obj_feats = ['make','body']

for feat in obj_feats:
    df["{}_cat".format(feat)] = df[feat].factorize()[0]
    
cat_feats = [x for x in df.columns if "_cat" in x]
feats = cat_feats + num_feats
feats
# Out:
# ['make_cat', 'body_cat', 'odometer', 'year', 'condition']

# %%
#tworzymy predykcje i zapisujemy plik

df_train = df[ ~df["sellingprice"].isnull() ].copy()
df_test = df[ df["sellingprice"].isnull() ].copy()

X_train = df_train[feats]
y_train = df_train["sellingprice"]

X_test = df_test[feats]

model = xgb.XGBRegressor(max_depth=5, n_estimators=50, learning_rate=0.3, random_state=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)


df_test["sellingprice"] = y_pred
df_test.to_csv("predictions.csv", index=False)
